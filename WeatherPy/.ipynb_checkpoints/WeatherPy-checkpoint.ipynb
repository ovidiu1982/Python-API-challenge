# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
               
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ushuaia
# Processing Record 2 | Sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sokoni
# Processing Record 3 | Linqu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=linqu
# Processing Record 4 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=upernavik
# Processing Record 5 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saint george
# Processing Record 6 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hasaki
# Processing Record 7 | Asău
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=asau
# City not found. Skipping...
# Processing Record 8 | Churapcha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=churapcha
# Processing Record 9 | Mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mokhsogollokh
# Processing Record 10 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=christchurch
# Processing Record 11 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hilo
# City not found. Skipping...
# Processing Record 12 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=atuona
# Processing Record 13 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mataura
# Processing Record 14 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=busselton
# Processing Record 15 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=athabasca
# Processing Record 16 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=matara
# City not found. Skipping...
# Processing Record 17 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yellowknife
# Processing Record 18 | Linxia Chengguanzhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=linxia
# Processing Record 19 | Vagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vagay
# City not found. Skipping...
# Processing Record 20 | Caxias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=caxias
# Processing Record 21 | Bhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bhan
# Processing Record 22 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hobyo
# Processing Record 23 | Ganzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ganzhou
# Processing Record 24 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=albany
# Processing Record 25 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=husavik
# Processing Record 26 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tiksi
# City not found. Skipping...
# Processing Record 27 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mar del plata
# City not found. Skipping...
# Processing Record 28 | St. George's
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saint-georges
# Processing Record 29 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=rikitea
# Processing Record 30 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hirara
# Processing Record 31 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=talnakh
# Processing Record 32 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cidreira
# Processing Record 33 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yulara
# Processing Record 34 | Tsimmerbude
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=svetlyy
# Processing Record 35 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saint-philippe
# Processing Record 36 | Lumphat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lumphat
# Processing Record 37 | Alghero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=alghero
# Processing Record 38 | Bulolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bulolo
# Processing Record 39 | Nogliki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nogliki
# Processing Record 40 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=qaanaaq
# Processing Record 41 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=isangel
# Processing Record 42 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=henties bay
# Processing Record 43 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=arraial do cabo
# Processing Record 44 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=puerto ayora
# Processing Record 45 | Puro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=puro
# Processing Record 46 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=castro
# Processing Record 47 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=muros
# Processing Record 48 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mount gambier
# Processing Record 49 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=adrar
# Processing Record 50 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hobart
# Processing Record 51 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=puerto colombia
# Processing Record 52 | Saint Paul Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kodiak
# Processing Record 53 | Bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bam
# Processing Record 54 | Benalla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=benalla
# Processing Record 55 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=guerrero negro
# Processing Record 56 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dikson
# Processing Record 57 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aklavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 58 | Pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pimentel
# City not found. Skipping...
# Processing Record 59 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kruisfontein
# Processing Record 60 | Otjiwarongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=otjiwarongo
# Processing Record 61 | Tecpan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tecpan
# Processing Record 62 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vanimo
# Processing Record 63 | Ilog
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ilog
# Processing Record 64 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=longyearbyen
# Processing Record 65 | Pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pucallpa
# Processing Record 66 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bengkulu
# Processing Record 67 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=chuy
# Processing Record 68 | Kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kapuskasing
# Processing Record 69 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=karratha
# Processing Record 70 | La Baule-Escoublac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=la baule-escoublac
# Processing Record 71 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ribeira grande
# Processing Record 72 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cape town
# Processing Record 73 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aquiraz
# Processing Record 74 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vaini
# Processing Record 75 | Terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=terrace
# Processing Record 76 | Serenje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=serenje
# Processing Record 77 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hermanus
# Processing Record 78 | Kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kangaatsiaq
# Processing Record 79 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=punta arenas
# Processing Record 80 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=georgetown
# Processing Record 81 | Shibetsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=shibetsu
# Processing Record 82 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bilma
# Processing Record 83 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=atambua
# Processing Record 84 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=evensk
# Processing Record 85 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port hardy
# Processing Record 86 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=alice springs
# Processing Record 87 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=jamestown
# Processing Record 88 | Porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=porbandar
# Processing Record 89 | Buta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=buta
# Processing Record 90 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=thompson
# Processing Record 91 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saldanha
# Processing Record 92 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ostrovnoy
# Processing Record 93 | Tshela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tshela
# Processing Record 94 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cherskiy
# Processing Record 95 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=avarua
# Processing Record 96 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pevek
# Processing Record 97 | Aberchirder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aberchirder
# Processing Record 98 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=quelimane
# Processing Record 99 | Al Bardīyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bardiyah
# Processing Record 100 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=clyde river
# Processing Record 101 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=airai
# Processing Record 102 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=victoria
# Processing Record 103 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=olafsvik
# Processing Record 104 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bluff
# Processing Record 105 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vila franca do campo
# Processing Record 106 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bambanglipuro
# Processing Record 107 | Plouzané
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=plouzane
# Processing Record 108 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=barrow
# Processing Record 109 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=new norfolk
# Processing Record 110 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port alfred
# Processing Record 111 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=comodoro rivadavia
# Processing Record 112 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pacific grove
# Processing Record 113 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bambous virieux
# Processing Record 114 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=chokurdakh
# Processing Record 115 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ancud
# City not found. Skipping...
# Processing Record 116 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saskylakh
# Processing Record 117 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=saint-augustin
# Processing Record 118 | Moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=moree
# Processing Record 119 | Adeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=adeje
# Processing Record 120 | Erdenet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=erdenet
# Processing Record 121 | Keti Bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=keti bandar
# Processing Record 122 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=naze
# Processing Record 123 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cabo san lucas
# Processing Record 124 | Wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wuwei
# Processing Record 125 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=katsuura
# Processing Record 126 | Bida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bida
# Processing Record 127 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bara
# Processing Record 128 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=leningradskiy
# Processing Record 129 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cockburn town
# Processing Record 130 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nouadhibou
# Processing Record 131 | Arrondissement de Dreux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dreux
# Processing Record 132 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ulladulla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 133 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dunedin
# Processing Record 134 | Manadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=manadhoo
# Processing Record 135 | Ongandjera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ongandjera
# City not found. Skipping...
# Processing Record 136 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=te anau
# Processing Record 137 | Litherland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=litherland
# Processing Record 138 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=fairbanks
# Processing Record 139 | Binzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=binzhou
# Processing Record 140 | Utete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=utete
# Processing Record 141 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=college
# Processing Record 142 | Alingsås
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=alingsas
# Processing Record 143 | Qui Nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=qui nhon
# Processing Record 144 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kenai
# Processing Record 145 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=buchanan
# Processing Record 146 | Ustka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ustka
# Processing Record 147 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=butaritari
# Processing Record 148 | Kurchum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kurchum
# Processing Record 149 | Bloomsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bloomsburg
# Processing Record 150 | Andra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=andra
# Processing Record 151 | Russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=russell
# Processing Record 152 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vao
# Processing Record 153 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=luganville
# Processing Record 154 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=faya
# City not found. Skipping...
# Processing Record 155 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kahului
# Processing Record 156 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nhulunbuy
# Processing Record 157 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sola
# Processing Record 158 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kavieng
# Processing Record 159 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=maningrida
# City not found. Skipping...
# Processing Record 160 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nago
# Processing Record 161 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=almaznyy
# Processing Record 162 | Kualakapuas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kualakapuas
# Processing Record 163 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bredasdorp
# Processing Record 164 | Prince Albert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=prince albert
# Processing Record 165 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port moresby
# Processing Record 166 | Klaksvík
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=klaksvik
# Processing Record 167 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=erenhot
# Processing Record 168 | Hobe Sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hobe sound
# Processing Record 169 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=margate
# Processing Record 170 | Colón
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=colon
# Processing Record 171 | Lensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lensk
# Processing Record 172 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=torbay
# Processing Record 173 | Khovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hovd
# Processing Record 174 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tasiilaq
# Processing Record 175 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=camacha
# Processing Record 176 | Berck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=berck
# Processing Record 177 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hofn
# Processing Record 178 | Markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=markova
# Processing Record 179 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=souillac
# Processing Record 180 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=chapais
# Processing Record 181 | Ndioum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ndioum
# Processing Record 182 | Mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mmabatho
# Processing Record 183 | Sainte-Anne-des-Monts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sainte-anne-des-monts
# Processing Record 184 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=carnarvon
# City not found. Skipping...
# Processing Record 185 | Severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=severodvinsk
# Processing Record 186 | Guozhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=guozhen
# City not found. Skipping...
# Processing Record 187 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=flin flon
# Processing Record 188 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kapaa
# Processing Record 189 | That Phanom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=that phanom
# Processing Record 190 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=geraldton
# Processing Record 191 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ponta delgada
# Processing Record 192 | Riosucio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=riosucio
# Processing Record 193 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=poum
# Processing Record 194 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kaitangata
# Processing Record 195 | Taft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=taft
# Processing Record 196 | Ndélé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ndele
# Processing Record 197 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nuuk
# Processing Record 198 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=westport
# Processing Record 199 | Qujing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=qujing
# Processing Record 200 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=santa maria
# Processing Record 201 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=harper
# Processing Record 202 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tura
# Processing Record 203 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=petropavlovsk-kamchatskiy
# Processing Record 204 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hithadhoo
# Processing Record 205 | Gaurnadi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=gaurnadi
# Processing Record 206 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=madang
# Processing Record 207 | Xinyu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=xinyu
# Processing Record 208 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=los llanos de aridane
# Processing Record 209 | Gaomi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=gaomi
# Processing Record 210 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kavaratti
# Processing Record 211 | Danville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=danville
# Processing Record 212 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=inhambane
# Processing Record 213 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=norman wells
# Processing Record 214 | City of Catbalogan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=catbalogan
# Processing Record 215 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=brae
# Processing Record 216 | Aragarças
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aragarcas
# Processing Record 217 | Zhalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=zalantun
# Processing Record 218 | Houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=houma
# Processing Record 219 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hualmay
# Processing Record 220 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=khatanga
# Processing Record 221 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hambantota
# City not found. Skipping...
# Processing Record 222 | Cap-Chat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cap-chat
# Processing Record 223 | Acapulco de Juárez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=acapulco
# Processing Record 224 | Shīeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=shieli
# Processing Record 225 | Sumenep
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sumenep
# Processing Record 226 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=east london
# Processing Record 227 | Thio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=thio
# City not found. Skipping...
# Processing Record 228 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sinnamary
# Processing Record 229 | Strelka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=strelka
# City not found. Skipping...
# Processing Record 230 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=itarema
# City not found. Skipping...
# Processing Record 231 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=olinda
# City not found. Skipping...
# Processing Record 232 | Mezen'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mezen
# City not found. Skipping...
# Processing Record 233 | Deputatsky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=deputatskiy
# Processing Record 234 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yeppoon
# Processing Record 235 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hamilton
# Processing Record 236 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=laguna
# City not found. Skipping...
# Processing Record 237 | Paoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=paoua
# Processing Record 238 | Sikeston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sikeston
# Processing Record 239 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=atar
# Processing Record 240 | Bata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bata
# Processing Record 241 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=severo-kurilsk
# Processing Record 242 | Wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wajir
# Processing Record 243 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port elizabeth
# Processing Record 244 | Yuzhno-Sukhokumsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yuzhno-sukhokumsk
# City not found. Skipping...
# Processing Record 245 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=poya
# Processing Record 246 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nome
# City not found. Skipping...
# Processing Record 247 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mayor pablo lagerenza
# Processing Record 248 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=jalu
# City not found. Skipping...
# Processing Record 249 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=fortuna
# Processing Record 250 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pisco
# Processing Record 251 | Doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=doka
# Processing Record 252 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tuktoyaktuk
# Processing Record 253 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nikolskoye
# Processing Record 254 | Alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=alexandria
# Processing Record 255 | Pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pandan
# Processing Record 256 | Mazagão
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mazagao
# Processing Record 257 | Wahpeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wahpeton
# Processing Record 258 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=launceston
# Processing Record 259 | Nyaunglebin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nyaunglebin
# Processing Record 260 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=karasjok
# Processing Record 261 | Panama City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=panama city
# Processing Record 262 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lavrentiya
# Processing Record 263 | Manyana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=manyana
# Processing Record 264 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=zhangjiakou
# Processing Record 265 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=srednekolymsk
# Processing Record 266 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=marsh harbour
# Processing Record 267 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hervey bay
# Processing Record 268 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ginir
# City not found. Skipping...
# Processing Record 269 | Ouargaye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ouargaye
# Processing Record 270 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=huarmey
# Processing Record 271 | Erzincan Province
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=erzincan
# Processing Record 272 | Praia da Vitória
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=praia da vitoria
# Processing Record 273 | Ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ayr
# Processing Record 274 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=boa vista
# Processing Record 275 | Griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=griffith
# Processing Record 276 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=san patricio
# Processing Record 277 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tautira
# Processing Record 278 | Tetiiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tetiyiv
# Processing Record 279 | San Jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=san jose
# Processing Record 280 | Krapivinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=krapivinskiy
# Processing Record 281 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=zhangye
# Processing Record 282 | Mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mao
# Processing Record 283 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=samarai
# Processing Record 284 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yanam
# Processing Record 285 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port blair
# Processing Record 286 | Lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lamar
# Processing Record 287 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tezu
# Processing Record 288 | Vanderhoof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vanderhoof
# Processing Record 289 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=trincomalee
# Processing Record 290 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=broome
# Processing Record 291 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dingle
# Processing Record 292 | Pombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pombia
# Processing Record 293 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ilulissat
# Processing Record 294 | Ereymentau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ereymentau
# Processing Record 295 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=narsaq
# Processing Record 296 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=haines junction
# Processing Record 297 | Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=canutama
# Processing Record 298 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=paamiut
# Processing Record 299 | Princeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=princeton
# Processing Record 300 | Dabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dabat
# Processing Record 301 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pitimbu
# Processing Record 302 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aksarka
# Processing Record 303 | Briançon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=briancon
# Processing Record 304 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=solnechnyy
# Processing Record 305 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ukiah
# Processing Record 306 | Cuamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cuamba
# Processing Record 307 | Lubango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lubango
# Processing Record 308 | Vīsāvadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=visavadar
# Processing Record 309 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lompoc
# Processing Record 310 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=manta
# Processing Record 311 | Apúlia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=apulia
# Processing Record 312 | Sittwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=akyab
# Processing Record 313 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vila velha
# City not found. Skipping...
# Processing Record 314 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=padang
# Processing Record 315 | Marmaris
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=marmaris
# Processing Record 316 | Aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aginskoye
# Processing Record 317 | Petrolina de Goiás
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=petrolina de goias
# Processing Record 318 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=makakilo city
# City not found. Skipping...
# Processing Record 319 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=leshukonskoye
# Processing Record 320 | Vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vanavara
# Processing Record 321 | Malaya Serdoba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=malaya serdoba
# Processing Record 322 | Mango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mango
# Processing Record 323 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wanning
# Processing Record 324 | Wattegama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wattegama
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=manavalakurichi
# Processing Record 462 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=bubaque
# Processing Record 463 | Dubno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dubno
# Processing Record 464 | Rathdrum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=rathdrum
# Processing Record 465 | Arrondissement du Havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=havre
# Processing Record 466 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=oussouye
# Processing Record 467 | Pinheiro Machado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pinheiro machado
# Processing Record 468 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=beringovskiy
# Processing Record 469 | Mahébourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mahebourg
# Processing Record 470 | Sørland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sorland
# Processing Record 471 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kudahuvadhoo
# Processing Record 472 | Hazorasp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=hazorasp
# Processing Record 473 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=lorengau
# Processing Record 474 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=great yarmouth
# Processing Record 475 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=port lincoln
# Processing Record 476 | Grasse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=grasse
# Processing Record 477 | Kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kalianget
# Processing Record 478 | La Constancia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=constancia
# Processing Record 479 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=alofi
# Processing Record 480 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ketchikan
# Processing Record 481 | Kaluzhskaya Oblast’
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kaluga
# Processing Record 482 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cairns
# Processing Record 483 | Dabola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=dabola
# Processing Record 484 | Key Largo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=key largo
# Processing Record 485 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=daru
# Processing Record 486 | Galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=galle
# Processing Record 487 | Kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kulhudhuffushi
# Processing Record 488 | Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kurilsk
# Processing Record 489 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mehamn
# Processing Record 490 | Van
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=van
# Processing Record 491 | Shingū
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=shingu
# Processing Record 492 | Galich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=galich
# City not found. Skipping...
# Processing Record 493 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=cayenne
# Processing Record 494 | Autazes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=autazes
# Processing Record 495 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vestmanna
# Processing Record 496 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=shimoda
# City not found. Skipping...
# Processing Record 497 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=zhigansk
# Processing Record 498 | Lianhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nancha
# Processing Record 499 | Paraty
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=parati
# Processing Record 500 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=necochea
# Processing Record 501 | Kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kerema
# Processing Record 502 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kamenka
# Processing Record 503 | Wangkui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wangkui
# Processing Record 504 | Ouésso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=ouesso
# Processing Record 505 | Elmadağ
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=elmadag
# Processing Record 506 | San Jerónimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=san jeronimo
# Processing Record 507 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sioux lookout
# Processing Record 508 | Vorontsovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vorontsovka
# Processing Record 509 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=qasigiannguit
# Processing Record 510 | Troitskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=troitskoye
# Processing Record 511 | Vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vangaindrano
# Processing Record 512 | Chinsali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=chinsali
# Processing Record 513 | Batamshinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=batamshinskiy
# Processing Record 514 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=rawson
# Processing Record 515 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=avera
# Processing Record 516 | Nkoteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=nkoteng
# Processing Record 517 | Krasnosel'kup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=krasnoselkup
# City not found. Skipping...
# Processing Record 518 | Berlevåg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=berlevag
# Processing Record 519 | Barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=barguzin
# Processing Record 520 | San Juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=san juan
# City not found. Skipping...
# Processing Record 521 | Maha Sarakham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=maha sarakham
# Processing Record 522 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=khasan
# Processing Record 523 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=riyadh
# Processing Record 524 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=quatre cocos
# Processing Record 525 | Stokmarknes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=stokmarknes
# Processing Record 526 | Pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=pyaozerskiy
# Processing Record 527 | Kristinestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kristiinankaupunki
# Processing Record 528 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=luwuk
# Processing Record 529 | Novo Aripuanã
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=novo aripuana
# Processing Record 530 | Raja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=raga
# Processing Record 531 | Stillwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=stillwater
# Processing Record 532 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=caravelas
# Processing Record 533 | Wenden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=wenden
# Processing Record 534 | Oruzgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=uruzgan
# Processing Record 535 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sur
# Processing Record 536 | Puerto Carreño
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=puerto carreno
# Processing Record 537 | Luyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=luyang
# Processing Record 538 | Tūkrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=tukrah
# Processing Record 539 | Coaticook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=coaticook
# Processing Record 540 | Shitanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=shitanjing
# Processing Record 541 | Orbetello
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=orbetello
# City not found. Skipping...
# Processing Record 542 | Esim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=axim
# Processing Record 543 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=santa rosa
# Processing Record 544 | Caconda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=caconda
# Processing Record 545 | Coahuayana Viejo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=coahuayana
# Processing Record 546 | Santa Vitória do Palmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=santa vitoria do palmar
# Processing Record 547 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=puerto escondido
# Processing Record 548 | Mokhotlong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mokhotlong
# Processing Record 549 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=baruun-urt
# City not found. Skipping...
# Processing Record 550 | Marystown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=marystown
# Processing Record 551 | Mankono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=mankono
# City not found. Skipping...
# Processing Record 552 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=praya
# City not found. Skipping...
# Processing Record 553 | Uyuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=uyuni
# Processing Record 554 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=buala
# Processing Record 555 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kisangani
# Processing Record 556 | Riberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=riberalta
# Processing Record 557 | Poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=poso
# Processing Record 558 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=yar-sale
# Processing Record 559 | Vynohradove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=vynohradove
# Processing Record 560 | General Pico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=general pico
# Processing Record 561 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kalmunai
# Processing Record 562 | Teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=teguise
# Processing Record 563 | Korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=korla
# Processing Record 564 | Caxito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=caxito
# Processing Record 565 | Aswān
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=aswan
# Processing Record 566 | Kula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=kula
# Processing Record 567 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=roma
# Processing Record 568 | São Sepé
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7dede6efed11903498a2e0059c26b902&q=sao sepe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0       Ushuaia          75      AR  1638730640        71 -54.8000  -68.3000
# 1        Sokoni         100      TZ  1638730345        75  -6.4333   39.5500
# 2         Linqu          70      CN  1638730643        58  36.5156  118.5397
# 3     Upernavik         100      GL  1638730644        73  72.7868  -56.1549
# 4  Saint George           6      US  1638730645        26  37.1041 -113.5841
#
#    Max Temp  Wind Speed
# 0     46.06       33.38
# 1     80.46        9.01
# 2     40.50        5.50
# 3     27.75        1.41
# 4     68.34        3.02

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
weather_data.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  568.000000  5.680000e+02  568.000000  568.000000  568.000000
# mean    59.367958  1.638731e+09   72.427817   21.018324   18.164800
# std     40.450638  2.630745e+02   20.385917   32.485951   91.071319
# min      0.000000  1.638730e+09   10.000000  -54.800000 -175.200000
# 25%     13.000000  1.638731e+09   63.000000   -6.458450  -62.250575
# 50%     75.000000  1.638731e+09   76.000000   26.573200   20.613200
# 75%    100.000000  1.638731e+09   87.000000   48.129425  102.334775
# max    100.000000  1.638731e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  568.000000  568.000000
# mean    53.078785    8.197271
# std     29.073401    6.444733
# min    -48.640000    0.000000
# 25%     32.610000    3.440000
# 50%     62.950000    6.575000
# 75%     76.810000   10.687500
# max     95.760000   42.770000

# %%
# Save data frame to CSV
weather_data.to_csv('output_data/weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0       Ushuaia          75      AR  1638730640        71 -54.8000  -68.3000
# 1        Sokoni         100      TZ  1638730345        75  -6.4333   39.5500
# 2         Linqu          70      CN  1638730643        58  36.5156  118.5397
# 3     Upernavik         100      GL  1638730644        73  72.7868  -56.1549
# 4  Saint George           6      US  1638730645        26  37.1041 -113.5841
#
#    Max Temp  Wind Speed
# 0     46.06       33.38
# 1     80.46        9.01
# 2     40.50        5.50
# 3     27.75        1.41
# 4     68.34        3.02

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a dataframe for the northern hemisphere
north_df = weather_data[weather_data.Lat > 0]

# Create x and y values
x_values = north_df["Max Temp"]
y_values = north_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Max Temp")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Northern Hemisphere - Max Temp vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.7528772432516565

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a dataframe for the northern hemisphere
south_df = weather_data[weather_data.Lat < 0]

# Create x and y values
x_values = south_df["Max Temp"]
y_values = south_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Max Temp")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Southern Hemisphere - Max Temp vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.46841390427060425

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create x and y values
x_values = north_df["Humidity"]
y_values = north_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Humidity")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Northern Hemisphere - Humidity (%) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.1746585076606799

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create x and y values
x_values = south_df["Humidity"]
y_values = south_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Humidity")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Southern Hemisphere - Humidity (%) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.055909452015898906

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create x and y values
x_values = north_df["Cloudiness"]
y_values = north_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Cloudiness")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Northern Hemisphere - Cloudiness (%) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.06272872484599054

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create x and y values
x_values = south_df["Cloudiness"]
y_values = south_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Cloudiness")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Southern Hemisphere - Cloudiness (%) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.026009905801701073

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create x and y values
x_values = north_df["Wind Speed"]
y_values = north_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Wind Speed")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Northern Hemisphere - Wind Speed (mph) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.03498004287005293

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df["Wind Speed"]
y_values = south_df["Lat"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.min(),y_values.min()),fontsize=15,color="red")

# Label plot
plt.xlabel("Wind Speed")
plt.ylabel("Lat")

# Print r square value
print(f"R squared: {rvalue**2}")

# Show and save plot
plt.savefig("Output_Plots/Southern Hemisphere - Wind Speed (mph) vs. Latitude.png")
plt.show()
# Out:
# R squared: 0.04787730967163803
